# %% [markdown]
# <a href="https://colab.research.google.com/github/galihww/PHI-Classification/blob/master/Concate_Dataset_PHI_and_NPHI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
lokasi_PHI = "/content/gdrive/MyDrive/1. Colab Notebooks/modul kecerdasan buatan/0. research text classification/Final Model/Preprocessing Dataset/datasetPHI_after_preprocessing.csv"
lokasi_NPHI = "/content/gdrive/MyDrive/1. Colab Notebooks/modul kecerdasan buatan/0. research text classification/Final Model/Preprocessing Dataset/datasetNPHI_after_preprocessing.csv"

# %% [markdown]
# # Read and Check PHI

# %%
import re
import numpy as np
import pandas as pd
import string
from sklearn import preprocessing, model_selection, naive_bayes, svm
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
data_PHI = pd.read_csv(lokasi_PHI)
data_PHI.head(10)
# Out:
#                                        Perkara-Final  Label
# 0  timbang  gugat surat gugat tanggal  oktober da...      0
# 1  timbang  gugat surat gugat tanggal februari  l...      0
# 2  timbang gugat surat gugat tanggal  desember la...      0
# 3  timbang  gugat surat gugat tanggal  februari d...      0
# 4  timbang  gugat surat gugat tanggal  april  daf...      0
# 5  timbang  gugat surat gugat tanggal april   ter...      0
# 6  timbang gugat surat gugat tanggal  oktober lam...      0
# 7  timbang  gugat surat gugat tanggal juni  lampi...      0
# 8  timbang  gugat surat gugat tanggal  februari l...      0
# 9  timbang  gugat aju gugat surat gugat tanggal j...      0

# %%
data_PHI.dropna(subset = ["Perkara-Final"], inplace=True)
data_PHI.count()
# Out:
# Perkara-Final    225
# Label            225
# dtype: int64

# %%
data_PHI.head()
# Out:
#                                        Perkara-Final  Label
# 0  timbang  gugat surat gugat tanggal  oktober da...      0
# 1  timbang  gugat surat gugat tanggal februari  l...      0
# 2  timbang gugat surat gugat tanggal  desember la...      0
# 3  timbang  gugat surat gugat tanggal  februari d...      0
# 4  timbang  gugat surat gugat tanggal  april  daf...      0

# %% [markdown]
# # Read and Check Non PHI

# %%
data_NPHI = pd.read_csv(lokasi_NPHI)
data_NPHI.head(10)
# Out:
#                                        Perkara-Final  Label
# 0  timbang  mohon berat surat mohon berat tanggal...      1
# 1  timbang  mohon surat mohon berat tanggal novem...      1
# 2  timbang  mohon berat surat berat tanggal agust...      1
# 3  timbang  mohon berat surat mohon berat tanggal...      1
# 4  timbang  mohon berat laku usaha surat berat ta...      1
# 5  timbang  mohon berat surat mohon berat tanggal...      1
# 6  timbang  gugat mohon berat surat gugat berat t...      1
# 7  timbang  mohon surat mohon berat tanggal  sept...      1
# 8  timbang  mohon surat mohon berat tanggal juni ...      1
# 9  timbang  mohon berat surat mohon berat tanggal...      1

# %%
data_NPHI.dropna(subset = ["Perkara-Final"], inplace=True)
data_NPHI.count()
# Out:
# Perkara-Final    225
# Label            225
# dtype: int64

# %%
data_PHI.head()
# Out:
#                                        Perkara-Final  Label
# 0  timbang  gugat surat gugat tanggal  oktober da...      0
# 1  timbang  gugat surat gugat tanggal februari  l...      0
# 2  timbang gugat surat gugat tanggal  desember la...      0
# 3  timbang  gugat surat gugat tanggal  februari d...      0
# 4  timbang  gugat surat gugat tanggal  april  daf...      0

# %% [markdown]
# # Concate

# %%
data_PHI = data_PHI.iloc[:225,:]
data_NPHI = data_NPHI.iloc[:225,:]
data_final = pd.concat([data_PHI,data_NPHI],ignore_index=True)
data_final
# Out:
#                                          Perkara-Final  Label
# 0    timbang  gugat surat gugat tanggal  oktober da...      0
# 1    timbang  gugat surat gugat tanggal februari  l...      0
# 2    timbang gugat surat gugat tanggal  desember la...      0
# 3    timbang  gugat surat gugat tanggal  februari d...      0
# 4    timbang  gugat surat gugat tanggal  april  daf...      0
# ..                                                 ...    ...
# 445  timbang  mohon surat mohon  berat  aju berat  ...      1
# 446  timbang  mohon berat surat mohon berat tanggal...      1
# 447  timbang  mohon berat laku usaha aju berat hada...      1
# 448  timbang  mohon berat surat mohon berat tanggal...      1
# 449  timbang  mohon surat mohon berat tanggal agust...      1
#
# [450 rows x 2 columns]

# %%
data_final.Label.value_counts()
# Out:
# 1    225
# 0    225
# Name: Label, dtype: int64

# %%
data_final.to_csv('/content/gdrive/MyDrive/1. Colab Notebooks/modul kecerdasan buatan/0. research text classification/Final Model/Preprocessing Dataset/final_dataset.csv')
